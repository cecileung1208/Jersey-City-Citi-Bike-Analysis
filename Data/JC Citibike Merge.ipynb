# %%
import pandas as pd

# %% [markdown]
# ### Creating DF for 2016-2020

# %%
citi201801_data = pd.read_csv("JC-201801-citibike-tripdata.csv", error_bad_lines=False)
citi201802_data = pd.read_csv("JC-201802-citibike-tripdata.csv", error_bad_lines=False)
citi201803_data = pd.read_csv("JC-201803-citibike-tripdata.csv", error_bad_lines=False)
citi201804_data = pd.read_csv("JC-201804-citibike-tripdata.csv", error_bad_lines=False)
citi201805_data = pd.read_csv("JC-201805-citibike-tripdata.csv", error_bad_lines=False)
citi201806_data = pd.read_csv("JC-201806-citibike-tripdata.csv", error_bad_lines=False)
citi201807_data = pd.read_csv("JC-201807-citibike-tripdata.csv", error_bad_lines=False)
citi201808_data = pd.read_csv("JC-201808-citibike-tripdata.csv", error_bad_lines=False)
citi201809_data = pd.read_csv("JC-201809-citibike-tripdata.csv", error_bad_lines=False)
citi201810_data = pd.read_csv("JC-201810-citibike-tripdata.csv", error_bad_lines=False)
citi201811_data = pd.read_csv("JC-201811-citibike-tripdata.csv", error_bad_lines=False)
citi201812_data = pd.read_csv("JC-201812-citibike-tripdata.csv", error_bad_lines=False)

# %%
citi201901_data = pd.read_csv("JC-201901-citibike-tripdata.csv", error_bad_lines=False)
citi201902_data = pd.read_csv("JC-201902-citibike-tripdata.csv", error_bad_lines=False)
citi201903_data = pd.read_csv("JC-201903-citibike-tripdata.csv", error_bad_lines=False)
citi201904_data = pd.read_csv("JC-201904-citibike-tripdata.csv", error_bad_lines=False)
citi201905_data = pd.read_csv("JC-201905-citibike-tripdata.csv", error_bad_lines=False)
citi201906_data = pd.read_csv("JC-201906-citibike-tripdata.csv", error_bad_lines=False)
citi201907_data = pd.read_csv("JC-201907-citibike-tripdata.csv", error_bad_lines=False)
citi201908_data = pd.read_csv("JC-201908-citibike-tripdata.csv", error_bad_lines=False)
citi201909_data = pd.read_csv("JC-201909-citibike-tripdata.csv", error_bad_lines=False)
citi201910_data = pd.read_csv("JC-201910-citibike-tripdata.csv", error_bad_lines=False)
citi201911_data = pd.read_csv("JC-201911-citibike-tripdata.csv", error_bad_lines=False)
citi201912_data = pd.read_csv("JC-201912-citibike-tripdata.csv", error_bad_lines=False)

# %%
citi202001_data = pd.read_csv("JC-202001-citibike-tripdata.csv", error_bad_lines=False)
citi202002_data = pd.read_csv("JC-202002-citibike-tripdata.csv", error_bad_lines=False)
citi202003_data = pd.read_csv("JC-202003-citibike-tripdata.csv", error_bad_lines=False)
citi202004_data = pd.read_csv("JC-202004-citibike-tripdata.csv", error_bad_lines=False)
citi202005_data = pd.read_csv("JC-202005-citibike-tripdata.csv", error_bad_lines=False)
citi202006_data = pd.read_csv("JC-202006-citibike-tripdata.csv", error_bad_lines=False)
citi202007_data = pd.read_csv("JC-202007-citibike-tripdata.csv", error_bad_lines=False)
citi202008_data = pd.read_csv("JC-202008-citibike-tripdata.csv", error_bad_lines=False)
citi202009_data = pd.read_csv("JC-202009-citibike-tripdata.csv", error_bad_lines=False)
citi202010_data = pd.read_csv("JC-202010-citibike-tripdata.csv", error_bad_lines=False)
citi202011_data = pd.read_csv("JC-202011-citibike-tripdata.csv", error_bad_lines=False)
citi202012_data = pd.read_csv("JC-202012-citibike-tripdata.csv", error_bad_lines=False)

# %%
citi2018_frames = [citi201801_data, citi201802_data, citi201803_data, citi201804_data, citi201805_data, citi201806_data , citi201807_data, citi201808_data, citi201809_data, citi201810_data, citi201811_data, citi201812_data]
citi_2018 = pd.concat(citi2018_frames)
citi_2018
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1               550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2               510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3               354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4               250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# ...             ...                       ...                       ...
# 20200          1081  2018-12-22 11:51:46.0600  2018-12-22 12:09:47.4730
# 20201           344  2018-12-25 21:40:09.8660  2018-12-25 21:45:54.2670
# 20202          1233  2018-12-29 12:55:45.9690  2018-12-29 13:16:19.5960
# 20203          1057  2018-12-30 15:32:09.3320  2018-12-30 15:49:46.3510
# 20204           301  2018-12-31 16:34:11.9340  2018-12-31 16:39:13.8340
#
#        start station id start station name  start station latitude  \
# ...

# %%
citi2019_frames = [citi201901_data, citi201902_data, citi201903_data, citi201904_data, citi201905_data, citi201906_data , citi201907_data, citi201908_data, citi201909_data, citi201910_data, citi201911_data, citi201912_data]
citi_2019 = pd.concat(citi2019_frames)
citi_2019
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...             ...                       ...                       ...
# 19723           283  2019-12-31 23:12:18.5480  2019-12-31 23:17:01.8740
# 19724           267  2019-12-31 23:19:03.5840  2019-12-31 23:23:30.6640
# 19725           379  2019-12-31 23:19:06.5830  2019-12-31 23:25:25.7970
# 19726           188  2019-12-31 23:24:00.2630  2019-12-31 23:27:09.0400
# 19727           326  2019-12-31 23:45:20.9780  2019-12-31 23:50:47.7490
#
#        start station id start station name  start station latitude  \
# ...

# %%
citi2020_frames = [citi202001_data, citi202002_data, citi202003_data, citi202004_data, citi202005_data, citi202006_data , citi202007_data, citi202008_data, citi202009_data, citi202010_data, citi202011_data, citi202012_data]
citi_2020 = pd.concat(citi2020_frames)
citi_2020
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1               377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2               288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3               435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4               231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %% [markdown]
# ### Putting all 2018-2020 DF into one DF

# %%
citi_frames_3yrs = [citi201801_data, citi201802_data, citi201803_data, citi201804_data, citi201805_data, citi201806_data , citi201807_data, citi201808_data, citi201809_data, citi201810_data, citi201811_data, citi201812_data,citi201901_data, citi201902_data, citi201903_data, citi201904_data, citi201905_data, citi201906_data , citi201907_data, citi201908_data, citi201909_data, citi201910_data, citi201911_data, citi201912_data, citi202001_data, citi202002_data, citi202003_data, citi202004_data, citi202005_data, citi202006_data , citi202007_data, citi202008_data, citi202009_data, citi202010_data, citi202011_data, citi202012_data]
citibike_JC_2018_to_2020 = pd.concat(citi_frames_3yrs)
citibike_JC_2018_to_2020
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1               550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2               510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3               354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4               250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
citibike_JC_2018_to_2020= citibike_JC_2018_to_2020[citibike_JC_2018_to_2020['birth year'] > 1940]
citibike_JC_2018_to_2020
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1               550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2               510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3               354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4               250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
citibike_JC_2018_to_2020 = citibike_JC_2018_to_2020[citibike_JC_2018_to_2020['gender'] > 0]
citibike_JC_2018_to_2020
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1               550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2               510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3               354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4               250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# ...             ...                       ...                       ...
# 11682           591  2020-12-31 22:10:54.8540  2020-12-31 22:20:46.1760
# 11683           585  2020-12-31 22:11:08.4300  2020-12-31 22:20:53.8980
# 11687           653  2020-12-31 22:38:25.4680  2020-12-31 22:49:18.5150
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
citibike_JC_2018_to_2020=citibike_JC_2018_to_2020.dropna()
citibike_JC_2018_to_2020
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1               550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2               510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3               354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4               250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# ...             ...                       ...                       ...
# 11682           591  2020-12-31 22:10:54.8540  2020-12-31 22:20:46.1760
# 11683           585  2020-12-31 22:11:08.4300  2020-12-31 22:20:53.8980
# 11687           653  2020-12-31 22:38:25.4680  2020-12-31 22:49:18.5150
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
citibike_JC_2018_to_2020.to_csv("citibike_JC_2018_to_2020.csv")
